# %%
print("Namah Shivaya!")
# Out:
# Namah Shivaya!

# %%
a=int(input("Enter num1"))
b=int(input("Enter num2"))
sum=a+b
print("The sum is", sum)
# Out:
# Enter num1 5
# Enter num2 10
# The sum is 15

# %%
a=input("Enter username:")
print("Namah Shivaya,",a)
# Out:
# Enter username: Niranjan
# Namah Shivaya, Niranjan

# %%
l=int(input("Enter length of rectangle:"))
b=int(input("Enter breadth of rectangle:"))
area= l*b
print("The are of the given rectangle is",area)
# Out:
# Enter length of rectangle: 5
# Enter breadth of rectangle: 10
# The are of the given rectangle is 50

# %%
a=int(input("Enter the value in celcius:"))
conv=a*(9/5)+32
print("The value of temp in fara]enheat is",conv)
# Out:
# Enter the value in celcius: 5
# The value of temp in fara]enheat is 41.0
