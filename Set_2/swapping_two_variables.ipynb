# %%
a=10
b=5
print("Present value of a:",a)
print("Present value of b:",b)
a,b=b,a
print("Final value of a:",a)
print("Final value of b:",b)
# Out:
# Present value of a: 10
# Present value of b: 5
# Final value of a: 5
# Final value of b: 10
